# %%
import plotly.graph_objects as go
import pandas as pd
import meusmetodos as mm

# %%
df = mm.criar_df('statusinvest-busca-avancada.csv')


df
# Out:
# TICKER;PRECO;DY;P/L;P/VP;P/ATIVOS;MARGEM BRUTA;MARGEM EBIT;MARG. LIQUIDA;P/EBIT;EV/EBIT;DIVIDA LIQUIDA / EBIT;DIV. LIQ. / PATRI.;PSR;P/CAP. GIRO;P. AT CIR. LIQ.;LIQ. CORRENTE;ROE;ROA;ROIC;PATRIMONIO / ATIVOS;PASSIVOS / ATIVOS;GIRO ATIVOS;CAGR RECEITAS 5 ANOS;CAGR LUCROS 5 ANOS; LIQUIDEZ MEDIA DIARIA; VPA; LPA; PEG Ratio; VALOR DE MERCADO
#     TICKER  PRECO    DY    P/L   P/VP P/ATIVOS MARGEM BRUTA MARGEM EBIT  \
# 0    AALR3  15,10   NaN  -8,18   1,60     0,66        29,80        3,29
# 1    ABCB4  21,83  6,99   6,05   0,91     0,09        16,03        9,38
# 2    ABEV3  13,09  5,58  14,33   2,17     1,44        50,83       23,88
# 3    ADHM3   1,56   NaN  -4,09  -1,29   105,12       100,00  -13.548,48
# 4    AERI3   6,07   NaN  -2,56   0,34     0,10        11,07        5,44
# ..     ...    ...   ...    ...    ...      ...          ...         ...
# 599  WIZC3   5,80  4,25   5,33   1,69     0,37        63,00       43,39
# ...

# %%
mm.grafico_radar(df)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Mauricio\Python\testes\.venv\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'categorias'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 mm.grafico_radar(df)
#
# ...
